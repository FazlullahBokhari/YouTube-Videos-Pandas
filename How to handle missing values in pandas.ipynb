# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('bigmart_test.csv')

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
data.shape
# Out:
# (5681, 11)

# %%
data_row = data.dropna(axis=0)

# %%
data_row
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 5              FDH56        9.800          Regular         0.063817
# 6              FDL48       19.350          Regular         0.082602
# 13             FDU11        4.785          Low Fat         0.092738
# 14             DRL59       16.750               LF         0.021206
# ...              ...          ...              ...              ...
# 5673           FDF46        7.070          Low Fat         0.094053
# 5674           DRL35       15.700          Low Fat         0.030704
# 5675           FDW46       13.000          Regular         0.070411
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0               Snack Foods  107.8622            OUT049
# ...

# %%
data_row.shape
# Out:
# (3099, 11)

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
data_col = data.dropna(axis=1)

# %%
data_col
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility           Item_Type  \
# 0              FDW58          Low Fat         0.007565         Snack Foods
# 1              FDW14              reg         0.038428               Dairy
# 2              NCN55          Low Fat         0.099575              Others
# 3              FDQ58          Low Fat         0.015388         Snack Foods
# 4              FDY38          Regular         0.118599               Dairy
# ...              ...              ...              ...                 ...
# 5676           FDB58          Regular         0.013496         Snack Foods
# 5677           FDD47          Regular         0.142991       Starchy Foods
# 5678           NCO17          Low Fat         0.073529  Health and Hygiene
# 5679           FDJ26          Regular         0.000000              Canned
# 5680           FDU37          Regular         0.104720              Canned
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
data_col.shape
# Out:
# (5681, 9)

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
fill = data.fillna(value="????")

# %%
fill
# Out:
#      Item_Identifier Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.75          Low Fat         0.007565
# 1              FDW14         8.3              reg         0.038428
# 2              NCN55        14.6          Low Fat         0.099575
# 3              FDQ58       7.315          Low Fat         0.015388
# 4              FDY38        ????          Regular         0.118599
# ...              ...         ...              ...              ...
# 5676           FDB58        10.5          Regular         0.013496
# 5677           FDD47         7.6          Regular         0.142991
# 5678           NCO17          10          Low Fat         0.073529
# 5679           FDJ26        15.3          Regular         0.000000
# 5680           FDU37         9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
data_item_weight = data['Item_Weight']

# %%
data_item_weight
# Out:
# 0       20.750
# 1        8.300
# 2       14.600
# 3        7.315
# 4          NaN
#          ...
# 5676    10.500
# 5677     7.600
# 5678    10.000
# 5679    15.300
# 5680     9.500
# Name: Item_Weight, Length: 5681, dtype: float64

# %%
mean = data_item_weight.mean()

# %%
mean
# Out:
# 12.695633368756642

# %%
fill_mean = data_item_weight.replace(np.NaN,mean)

# %%
fill_mean
# Out:
# 0       20.750000
# 1        8.300000
# 2       14.600000
# 3        7.315000
# 4       12.695633
#           ...
# 5676    10.500000
# 5677     7.600000
# 5678    10.000000
# 5679    15.300000
# 5680     9.500000
# Name: Item_Weight, Length: 5681, dtype: float64

# %%
median = data_item_weight.median()

# %%
median
# Out:
# 12.5

# %%
data_item_weight
# Out:
# 0       20.750
# 1        8.300
# 2       14.600
# 3        7.315
# 4          NaN
#          ...
# 5676    10.500
# 5677     7.600
# 5678    10.000
# 5679    15.300
# 5680     9.500
# Name: Item_Weight, Length: 5681, dtype: float64

# %%
fill_median = data_item_weight.replace(np.NaN, median)

# %%
fill_median
# Out:
# 0       20.750
# 1        8.300
# 2       14.600
# 3        7.315
# 4       12.500
#          ...
# 5676    10.500
# 5677     7.600
# 5678    10.000
# 5679    15.300
# 5680     9.500
# Name: Item_Weight, Length: 5681, dtype: float64

# %%
mode = data_item_weight.mode()

# %%
mode
# Out:
# 0    10.5
# dtype: float64
